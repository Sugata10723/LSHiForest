# %%
import sys

# 親ディレクトリのパスを直接追加
sys.path.append('/Users/ham/Desktop/LSHiforest')

import numpy as np
import pandas as pd
from CLSHiForest import CLSHiForest
from sklearn.metrics import accuracy_score

# %%
# データのインポート
df = pd.read_csv('csic_database.csv')
df.head()
df.nunique()

columns = ['Method', 'host', 'connection', 'lenght', 'content']
X = df[columns]
y_true = df['classification']

# %%
X.head()
# Out:
#   Method            host         connection              lenght  \
# 0    GET  localhost:8080              close                 NaN
# 1    GET  localhost:8080              close                 NaN
# 2   POST  localhost:8080  Connection: close  Content-Length: 68
# 3    GET  localhost:8080              close                 NaN
# 4   POST  localhost:8080  Connection: close  Content-Length: 63
#
#                                              content
# 0                                                NaN
# 1                                                NaN
# 2  id=3&nombre=Vino+Rioja&precio=100&cantidad=55&...
# 3                                                NaN
# 4  modo=entrar&login=choong&pwd=d1se3ci%F3n&remem...

# %%
normal_indices = np.where(y_true == 0)[0]
anomaly_indices = np.where(y_true == 1)[0]
train_normal_indices = normal_indices[:20000]
test_normal_indices = normal_indices[20000:]
train_indices = train_normal_indices
test_indices = np.concatenate([test_normal_indices, anomaly_indices])
X_train = X.iloc[train_indices]
y_train = y_true[train_indices]
X_test = X.iloc[test_indices]
y_test = y_true[test_indices]
print(f"トレーニングデータ: {len(X_train)}件 (すべて正常データ)")
print(f"テストデータ: {len(X_test)}件")
print(f" - 正常データ: {sum(y_test == 0)}件")
print(f" - 異常データ: {sum(y_test == 1)}件")
# Out:
# トレーニングデータ: 20000件 (すべて正常データ)
# テストデータ: 41065件
#  - 正常データ: 16000件
#  - 異常データ: 25065件

# %%
# モデル訓練・評価
model = CLSHiForest(n_trees=100, max_depth=10, hash_dim=10, min_samples=10, random_state=42)
model.fit(X_train)
scores = model.decision_function(X_test)

# %%
# 異常スコアの分布をプロット
model.plot_score_distribution(scores, y_test)

# %%
# AUC-ROCを計算
auc = model.plot_roc_curve(scores, y_test)

# %%
# 最初の木を可視化
model.visualize_tree(tree_index=0)
